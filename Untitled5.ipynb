# %%
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %% [raw]
# a=(1+2+3+\
# 4+5+6+\
# 7+8+9)
# print(a)

# %%
name = "Nikitha"
age = 21
salary = 40000
print(name,
      age,
      salary)
# Out:
# Nikitha 21 40000

# %%
name = "Nikitha"
age = 21
course = "MCA"

print(name)
print(age)
print(course)
# Out:
# Nikitha
# 21
# MCA

# %%
python = 90
sql = 85
dbms = 88

print(python)
print(sql)
print(dbms)
# Out:
# 90
# 85
# 88

# %%
brand = "Samsung"
price = 25000

print(brand)
print(price)
# Out:
# Samsung
# 25000

# %%
city = "Hyderabad"

print(city)
# Out:
# Hyderabad

# %%
employee_name = "Rahul"
employee_id = 1001
salary = 35000

print(employee_name)
print(employee_id)
# Out:
# Rahul
# 1001

# %%
patient = "Ramesh"
age = 45

# %%
name = "abc"

student_name = "xyz"

class = "MCA"
# Out:
#   Cell In[32], line 4
#     class = "MCA"
#           ^
# SyntaxError: invalid syntax

# %%
for i in range(3):
    print("*****")
    for i in range(3*3):
        print("*")
# Out:
# *****
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *****
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *****
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
print("    *      ")
print("  ****     ")
print(" ******    ")
for i in range(1):
    print("********")
    print("|      |")
    print("|      |")
    print("|  ||  |")
    print("|  ||  |")
    print("|______|")
# Out:
#     *
#   ****
#  ******
# ********
# |      |
# |      |
# |  ||  |
# |  ||  |
# |______|
